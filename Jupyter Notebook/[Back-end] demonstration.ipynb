# %%
import pandas as pd
import datetime

# %%
list_df = pd.read_excel("../Data/stock_list_error_free.xlsx")

list_df
# Out:
#       Unnamed: 0  SecuritiesCode  EffectiveDate  \
# 0              0            1301       20211230
# 1             19            1332       20211230
# 2             20            1333       20211230
# 3             26            1352       20211230
# 4             37            1375       20211230
# ...          ...             ...            ...
# 3771        4412            9994       20211230
# 3772        4413            9995       20211230
# 3773        4414            9996       20211230
# 3774        4415            9997       20211230
# 3775        4416           25935       20211230
#
#                                         Name             Section/Products  \
# 0                           KYOKUYO CO.,LTD.     First Section (Domestic)
# 1                  Nippon Suisan Kaisha,Ltd.     First Section (Domestic)
# 2                 Maruha Nichiro Corporation     First Section (Domestic)
# 3                         HOHSUI CORPORATION     First Section (Domestic)
# ...
