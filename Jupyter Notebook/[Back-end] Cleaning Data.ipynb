# %%
# import necessary libraries
import pandas as pd # pd is the convention to import pandas as
import datetime

# %% [markdown]
# # Data Overview

# %%
# read data
prices_df = pd.read_csv("../Data/stock_prices.csv")

# %%
# DO NOT INCLUDE IN FINAL PYTHON CODE
# preview data
prices_df
# Out:
#                 RowId        Date  SecuritiesCode    Open    High     Low  \
# 0       20211206_1301  2021-12-06            1301  2982.0  2982.0  2965.0
# 1       20211206_1332  2021-12-06            1332   592.0   599.0   588.0
# 2       20211206_1333  2021-12-06            1333  2368.0  2388.0  2360.0
# 3       20211206_1375  2021-12-06            1375  1230.0  1239.0  1224.0
# 4       20211206_1376  2021-12-06            1376  1339.0  1372.0  1339.0
# ...               ...         ...             ...     ...     ...     ...
# 111995  20220228_9990  2022-02-28            9990   511.0   518.0   509.0
# 111996  20220228_9991  2022-02-28            9991   823.0   825.0   814.0
# 111997  20220228_9993  2022-02-28            9993  1600.0  1622.0  1600.0
# 111998  20220228_9994  2022-02-28            9994  2568.0  2568.0  2540.0
# 111999  20220228_9997  2022-02-28            9997   731.0   737.0   726.0
#
#          Close   Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag  \
# 0       2971.0     8900               1.0               NaN            False
# 1        589.0  1360800               1.0               NaN            False
# 2       2377.0   125900               1.0               NaN            False
# 3       1224.0    81100               1.0               NaN            False
# 4       1351.0     6200               1.0               NaN            False
# ...        ...      ...               ...               ...              ...
# 111995   516.0   120600               1.0               NaN            False
# 111996   822.0    16200               1.0               NaN            False
# 111997  1600.0     4000               1.0               NaN            False
# 111998  2565.0     9000               1.0               NaN            False
# 111999   734.0   288100               1.0               NaN            False
#
#           Target
# 0      -0.003263
# 1      -0.008993
# 2      -0.009963
# 3      -0.015032
# 4       0.002867
# ...          ...
# 111995 -0.013592
# 111996 -0.020581
# 111997  0.005762
# 111998 -0.002341
# 111999 -0.030014
#
# [112000 rows x 12 columns]

# %% [markdown]
# # Handling Nulls

# %%
# DO NOT INCLUDE IN FINAL PYTHON CODE
# examine the number of nulls
prices_df.isnull().sum()
# Out:
# RowId                    0
# Date                     0
# SecuritiesCode           0
# Open                   284
# High                   284
# Low                    284
# Close                  284
# Volume                   0
# AdjustmentFactor         0
# ExpectedDividend    111497
# SupervisionFlag          0
# Target                   0
# dtype: int64

# %% [markdown]
# ##### Per the result above, we will not use column ExpectedDividend. We noted the number of nulls in Open, High, Low, and Close to be of somewhat concern, but will proceed regardless.

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# ### Remove Unused Columns

# %%
# remove unused column(s)
prices_df = prices_df.drop(['ExpectedDividend'], axis=1)

# %%
# DO NOT INCLUDE IN FINAL PYTHON CODE
# preview the dataframe after removed unused column(s)
prices_df.head()
# Out:
#            RowId        Date  SecuritiesCode    Open    High     Low   Close  \
# 0  20211206_1301  2021-12-06            1301  2982.0  2982.0  2965.0  2971.0
# 1  20211206_1332  2021-12-06            1332   592.0   599.0   588.0   589.0
# 2  20211206_1333  2021-12-06            1333  2368.0  2388.0  2360.0  2377.0
# 3  20211206_1375  2021-12-06            1375  1230.0  1239.0  1224.0  1224.0
# 4  20211206_1376  2021-12-06            1376  1339.0  1372.0  1339.0  1351.0
#
#     Volume  AdjustmentFactor  SupervisionFlag    Target
# 0     8900               1.0            False -0.003263
# 1  1360800               1.0            False -0.008993
# 2   125900               1.0            False -0.009963
# 3    81100               1.0            False -0.015032
# 4     6200               1.0            False  0.002867

# %% [markdown]
# ### Reformat Column "Date" into Datetime Format

# %%
# convert column "Date" into Datetime format
Datetime = pd.to_datetime(prices_df.Date, infer_datetime_format=True) # we can use infer_datetime_format = True here because the original format is already corresponding to the standard datetime format

# insert the new format into the dataframe
prices_df.insert(2, "Date_Datetime", Datetime, allow_duplicates = False)

# %% [markdown]
# ###### Why are we keeping the old "Date" column?
# ###### Datetime objects are proprietary to Python only. So, whenever the dataframe is re-exported, the values will be stored as strings.

# %%
# check the result of the conversion (note column Date_Datetime)
prices_df.dtypes
# Out:
# RowId                       object
# Date                        object
# Date_Datetime       datetime64[ns]
# SecuritiesCode               int64
# Open                       float64
# High                       float64
# Low                        float64
# Close                      float64
# Volume                       int64
# AdjustmentFactor           float64
# SupervisionFlag               bool
# Target                     float64
# dtype: object

# %% [markdown]
# # Testing Searching Speed

# %% [markdown]
# ###### We will search for the date 2022/02/28, SecuritiesCode 9997

# %%
prices_df
# Out:
#                 RowId        Date Date_Datetime  SecuritiesCode    Open  \
# 0       20211206_1301  2021-12-06    2021-12-06            1301  2982.0
# 1       20211206_1332  2021-12-06    2021-12-06            1332   592.0
# 2       20211206_1333  2021-12-06    2021-12-06            1333  2368.0
# 3       20211206_1375  2021-12-06    2021-12-06            1375  1230.0
# 4       20211206_1376  2021-12-06    2021-12-06            1376  1339.0
# ...               ...         ...           ...             ...     ...
# 111995  20220228_9990  2022-02-28    2022-02-28            9990   511.0
# 111996  20220228_9991  2022-02-28    2022-02-28            9991   823.0
# 111997  20220228_9993  2022-02-28    2022-02-28            9993  1600.0
# 111998  20220228_9994  2022-02-28    2022-02-28            9994  2568.0
# 111999  20220228_9997  2022-02-28    2022-02-28            9997   731.0
#
#           High     Low   Close   Volume  AdjustmentFactor  SupervisionFlag  \
# 0       2982.0  2965.0  2971.0     8900               1.0            False
# 1        599.0   588.0   589.0  1360800               1.0            False
# 2       2388.0  2360.0  2377.0   125900               1.0            False
# 3       1239.0  1224.0  1224.0    81100               1.0            False
# 4       1372.0  1339.0  1351.0     6200               1.0            False
# ...        ...     ...     ...      ...               ...              ...
# 111995   518.0   509.0   516.0   120600               1.0            False
# 111996   825.0   814.0   822.0    16200               1.0            False
# 111997  1622.0  1600.0  1600.0     4000               1.0            False
# 111998  2568.0  2540.0  2565.0     9000               1.0            False
# 111999   737.0   726.0   734.0   288100               1.0            False
#
#           Target
# 0      -0.003263
# 1      -0.008993
# 2      -0.009963
# 3      -0.015032
# 4       0.002867
# ...          ...
# 111995 -0.013592
# 111996 -0.020581
# 111997  0.005762
# 111998 -0.002341
# 111999 -0.030014
#
# [112000 rows x 12 columns]

# %%
# create datatime object
date_to_find = datetime.datetime(2022, 2, 28)

# find the High stock value
prices_df.loc[(prices_df['Date_Datetime'] == date_to_find) & (prices_df['SecuritiesCode'] == 9997), 'High']
# Out:
# 111999    737.0
# Name: High, dtype: float64

# %% [markdown]
# #### Took 0.9 seconds, satisfactory searching time.
