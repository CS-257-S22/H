# %%
# import libraries
import pandas as pd
import datetime

# %%
# load data
nasdaq_df = pd.read_csv("../Data/Polished/nasdaq_2010_mid.csv")
nasdaq_df["Date"] = pd.to_datetime(nasdaq_df["Date"])
nasdaq_df
# Out:
#              Date        Low       Open      Volume       High      Close  \
# 0      2010-01-15   5.430000   5.640000  10985300.0   5.840000   5.500000
# 1      2010-03-15   7.720000   7.880000   4790900.0   7.930000   7.900000
# 2      2010-04-15   7.250000   7.470000  15963500.0   7.490000   7.410000
# 3      2010-06-15   9.830000   9.830000  15766900.0  10.510000  10.460000
# 4      2010-07-15   8.850000   9.270000   6418800.0   9.290000   9.110000
# ...           ...        ...        ...         ...        ...        ...
# 150938 2021-10-15  39.450001  40.770000    338800.0  42.110001  39.549999
# 150939 2021-11-15  50.639999  51.730000    183700.0  52.040001  51.070000
# 150940 2021-12-15  45.610001  46.840000    305300.0  47.889999  47.549999
# 150941 2022-02-15  43.939999  43.939999    224200.0  45.709999  45.480000
# 150942 2022-03-15  40.099998  40.250000    500200.0  41.430000  41.090000
#
#         Adjusted Close Ticker Symbol
# 0             5.185079           AAL
# ...

# %%
# check data type
nasdaq_df.dtypes
# Out:
# Date              datetime64[ns]
# Low                      float64
# Open                     float64
# Volume                   float64
# High                     float64
# Close                    float64
# Adjusted Close           float64
# Ticker Symbol             object
# dtype: object
